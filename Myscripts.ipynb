# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

from time import sleep
from random import randint

# %%
titles = []
By = []
Valid_till= []
Bank = []
Deal_type= []
Card_type = []

# %%
headers = {"Accept-Language": "en-US, en;q=0.5"}

# %%
pages = np.arange(1, 4)
pages=[1,2,3]
offers=[]
for page in pages:
    page = requests.get("https://happycredit.in/kotak-mahindra-bank-offers/?page=" + str(page), headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    #print(soup.prettify())
    offers.append(soup.find_all('a', class_='coupon-cart others'))
    sleep(randint(2,10))

# %%
offers
# Out:
# [[<a class="coupon-cart others" href="/amazon-kotak-mahindra-bank-credit-card-emi-offer-337k/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Amazon Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/amazon.png"/></div><div class="right-clm"><h3>Amazon EMI Offer - 3, 6, 9 &amp; 12 Month EMI on Amazon</h3><div class="info"><p><span>By : <b>Amazon</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Amazon store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/flipkart-kotak-mahindra-bank-credit-card-emi-offer-xs4h/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Flipkart Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/flipkart.png"/></div><div class="right-clm"><h3>Flipkart EMI Offer- 3, 6, 9, 12, 18 and 24 Months EMI on Flipkart</h3><div class="info"><p><span>By : <b>Flipkart</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Flipkart store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Avail this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/flipkart-clothing-and-accessories-kotak-mahindra-bank-credit-card-emi-offer-ucgc/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Flipkart Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/flipkart.png"/></div><div class="right-clm"><h3>Avail Easy EMI on shopping on Flipkart</h3><div class="info"><p><span>By : <b>Flipkart</b></span><span class="valid">Valid Till : <b>Sep 22 - Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Flipkart store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  from Sep 22 to Dec 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/amazon-clothing-and-accessories-kotak-mahindra-bank-credit-card-emi-offer-8l3n/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Amazon Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/amazon.png"/></div><div class="right-clm"><h3>Avail Easy EMI &amp; no Processing Fee on Amazon using Kotak Mahindra Bank Cards</h3><div class="info"><p><span>By : <b>Amazon</b></span><span class="valid">Valid Till : <b>Sep 22 - Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Amazon store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  from Sep 22 to Dec 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/snapdeal-kotak-mahindra-bank-credit-card-emi-offer-fz4q/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Snapdeal Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/snap_deal.png"/></div><div class="right-clm"><h3>Snapdeal EMI Offer - 3, 6, 9 &amp; 12 Month EMI</h3><div class="info"><p><span>By : <b>Snapdeal</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Snapdeal store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Hurry up and make use of this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/paytm-kotak-mahindra-bank-credit-card-emi-offer-io05/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Paytm Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/paytm.png"/></div><div class="right-clm"><h3>Paytm EMI Offer - 3, 6, 9 &amp; 12 Months EMI on Paytm</h3><div class="info"><p><span>By : <b>Paytm</b></span><span class="valid">Valid Till : <b>Till Mar 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Paytm store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Mar 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/yatra-kotak-mahindra-bank-credit-card-emi-offer-kahd/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Yatra Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/yatra.png"/></div><div class="right-clm"><h3>Yatra EMI Offer - 3, 6, 9 &amp; 12 Month EMI</h3><div class="info"><p><span>By : <b>Yatra</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Yatra store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Hurry up and make use of this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/bookmyshow-kotak-mahindra-bank-credit-card-emi-offer-u4zx/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="BookMyShow Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/book_my_show.png"/></div><div class="right-clm"><h3>Bookmyshow EMI Offer - 3, 6, 9 &amp; 12 Month EMI</h3><div class="info"><p><span>By : <b>BookMyShow</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the BookMyShow store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Avail this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/goibibo-kotak-mahindra-bank-credit-card-emi-offer-qbhr/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Goibibo Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/goibibo.png"/></div><div class="right-clm"><h3>Goibibo EMI Offer - 3, 6, 9 &amp; 12 Month EMI on Goibibo</h3><div class="info"><p><span>By : <b>Goibibo</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Goibibo store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Hurry up and make use of this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/goibibo-flights-kotak-mahindra-bank-credit-card-emi-offer-b0ei/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Goibibo Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/goibibo.png"/></div><div class="right-clm"><h3>Avail Easy EMI &amp; no Processing Fee on Goibibo using Kotak Mahindra Bank Cards</h3><div class="info"><p><span>By : <b>Goibibo</b></span><span class="valid">Valid Till : <b>Sep 22 - Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Goibibo store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  from Sep 22 to Dec 31. Avail this offer now!</p></div></div></a>],
#  [<a class="coupon-cart others" href="/amazon-kotak-mahindra-bank-credit-card-emi-offer-337k/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Amazon Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/amazon.png"/></div><div class="right-clm"><h3>Amazon EMI Offer - 3, 6, 9 &amp; 12 Month EMI on Amazon</h3><div class="info"><p><span>By : <b>Amazon</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Amazon store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/flipkart-kotak-mahindra-bank-credit-card-emi-offer-xs4h/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Flipkart Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/flipkart.png"/></div><div class="right-clm"><h3>Flipkart EMI Offer- 3, 6, 9, 12, 18 and 24 Months EMI on Flipkart</h3><div class="info"><p><span>By : <b>Flipkart</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Flipkart store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Avail this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/flipkart-clothing-and-accessories-kotak-mahindra-bank-credit-card-emi-offer-ucgc/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Flipkart Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/flipkart.png"/></div><div class="right-clm"><h3>Avail Easy EMI on shopping on Flipkart</h3><div class="info"><p><span>By : <b>Flipkart</b></span><span class="valid">Valid Till : <b>Sep 22 - Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Flipkart store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  from Sep 22 to Dec 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/amazon-clothing-and-accessories-kotak-mahindra-bank-credit-card-emi-offer-8l3n/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Amazon Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/amazon.png"/></div><div class="right-clm"><h3>Avail Easy EMI &amp; no Processing Fee on Amazon using Kotak Mahindra Bank Cards</h3><div class="info"><p><span>By : <b>Amazon</b></span><span class="valid">Valid Till : <b>Sep 22 - Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Amazon store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  from Sep 22 to Dec 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/snapdeal-kotak-mahindra-bank-credit-card-emi-offer-fz4q/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Snapdeal Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/snap_deal.png"/></div><div class="right-clm"><h3>Snapdeal EMI Offer - 3, 6, 9 &amp; 12 Month EMI</h3><div class="info"><p><span>By : <b>Snapdeal</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Snapdeal store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Hurry up and make use of this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/paytm-kotak-mahindra-bank-credit-card-emi-offer-io05/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Paytm Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/paytm.png"/></div><div class="right-clm"><h3>Paytm EMI Offer - 3, 6, 9 &amp; 12 Months EMI on Paytm</h3><div class="info"><p><span>By : <b>Paytm</b></span><span class="valid">Valid Till : <b>Till Mar 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Paytm store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Mar 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/yatra-kotak-mahindra-bank-credit-card-emi-offer-kahd/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Yatra Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/yatra.png"/></div><div class="right-clm"><h3>Yatra EMI Offer - 3, 6, 9 &amp; 12 Month EMI</h3><div class="info"><p><span>By : <b>Yatra</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Yatra store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Hurry up and make use of this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/bookmyshow-kotak-mahindra-bank-credit-card-emi-offer-u4zx/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="BookMyShow Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/book_my_show.png"/></div><div class="right-clm"><h3>Bookmyshow EMI Offer - 3, 6, 9 &amp; 12 Month EMI</h3><div class="info"><p><span>By : <b>BookMyShow</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the BookMyShow store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Avail this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/goibibo-kotak-mahindra-bank-credit-card-emi-offer-qbhr/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Goibibo Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/goibibo.png"/></div><div class="right-clm"><h3>Goibibo EMI Offer - 3, 6, 9 &amp; 12 Month EMI on Goibibo</h3><div class="info"><p><span>By : <b>Goibibo</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Goibibo store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Hurry up and make use of this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/goibibo-flights-kotak-mahindra-bank-credit-card-emi-offer-b0ei/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Goibibo Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/goibibo.png"/></div><div class="right-clm"><h3>Avail Easy EMI &amp; no Processing Fee on Goibibo using Kotak Mahindra Bank Cards</h3><div class="info"><p><span>By : <b>Goibibo</b></span><span class="valid">Valid Till : <b>Sep 22 - Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Goibibo store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  from Sep 22 to Dec 31. Avail this offer now!</p></div></div></a>],
#  [<a class="coupon-cart others" href="/amazon-kotak-mahindra-bank-credit-card-emi-offer-337k/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Amazon Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/amazon.png"/></div><div class="right-clm"><h3>Amazon EMI Offer - 3, 6, 9 &amp; 12 Month EMI on Amazon</h3><div class="info"><p><span>By : <b>Amazon</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Amazon store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/flipkart-kotak-mahindra-bank-credit-card-emi-offer-xs4h/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Flipkart Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/flipkart.png"/></div><div class="right-clm"><h3>Flipkart EMI Offer- 3, 6, 9, 12, 18 and 24 Months EMI on Flipkart</h3><div class="info"><p><span>By : <b>Flipkart</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Flipkart store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Avail this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/flipkart-clothing-and-accessories-kotak-mahindra-bank-credit-card-emi-offer-ucgc/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Flipkart Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/flipkart.png"/></div><div class="right-clm"><h3>Avail Easy EMI on shopping on Flipkart</h3><div class="info"><p><span>By : <b>Flipkart</b></span><span class="valid">Valid Till : <b>Sep 22 - Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Flipkart store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  from Sep 22 to Dec 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/amazon-clothing-and-accessories-kotak-mahindra-bank-credit-card-emi-offer-8l3n/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Amazon Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/amazon.png"/></div><div class="right-clm"><h3>Avail Easy EMI &amp; no Processing Fee on Amazon using Kotak Mahindra Bank Cards</h3><div class="info"><p><span>By : <b>Amazon</b></span><span class="valid">Valid Till : <b>Sep 22 - Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Amazon store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  from Sep 22 to Dec 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/snapdeal-kotak-mahindra-bank-credit-card-emi-offer-fz4q/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Snapdeal Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/snap_deal.png"/></div><div class="right-clm"><h3>Snapdeal EMI Offer - 3, 6, 9 &amp; 12 Month EMI</h3><div class="info"><p><span>By : <b>Snapdeal</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Snapdeal store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Hurry up and make use of this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/paytm-kotak-mahindra-bank-credit-card-emi-offer-io05/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Paytm Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/paytm.png"/></div><div class="right-clm"><h3>Paytm EMI Offer - 3, 6, 9 &amp; 12 Months EMI on Paytm</h3><div class="info"><p><span>By : <b>Paytm</b></span><span class="valid">Valid Till : <b>Till Mar 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Paytm store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Mar 31. Book now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/yatra-kotak-mahindra-bank-credit-card-emi-offer-kahd/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Yatra Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/yatra.png"/></div><div class="right-clm"><h3>Yatra EMI Offer - 3, 6, 9 &amp; 12 Month EMI</h3><div class="info"><p><span>By : <b>Yatra</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Yatra store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Hurry up and make use of this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/bookmyshow-kotak-mahindra-bank-credit-card-emi-offer-u4zx/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="BookMyShow Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/book_my_show.png"/></div><div class="right-clm"><h3>Bookmyshow EMI Offer - 3, 6, 9 &amp; 12 Month EMI</h3><div class="info"><p><span>By : <b>BookMyShow</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the BookMyShow store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Avail this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/goibibo-kotak-mahindra-bank-credit-card-emi-offer-qbhr/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Goibibo Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/goibibo.png"/></div><div class="right-clm"><h3>Goibibo EMI Offer - 3, 6, 9 &amp; 12 Month EMI on Goibibo</h3><div class="info"><p><span>By : <b>Goibibo</b></span><span class="valid">Valid Till : <b>Till Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Goibibo store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  till Dec 31. Hurry up and make use of this offer now!</p></div></div></a>,
#   <a class="coupon-cart others" href="/goibibo-flights-kotak-mahindra-bank-credit-card-emi-offer-b0ei/"><div class="left-clm"><img alt="Kotak Mahindra Bank Offer" class="bnk-logo" src="https://happycredit.in/static/images/bank_logos/kotak_mahindra_bank.png"/><img alt="Goibibo Offer" class="bnk-logo" src="https://happycredit.in/static/images/store_logos/goibibo.png"/></div><div class="right-clm"><h3>Avail Easy EMI &amp; no Processing Fee on Goibibo using Kotak Mahindra Bank Cards</h3><div class="info"><p><span>By : <b>Goibibo</b></span><span class="valid">Valid Till : <b>Sep 22 - Dec 31</b></span><span>Bank  : <b>Kotak Mahindra Bank</b></span><span class="valid">Deal Type: <b>EMI</b></span><span class="valid">Card Type: <b>Credit</b></span></p><p class="info-txt">Avail this offer on every purchase on the Goibibo store for All Kotak Mahindra Bank Credit Cards holders. The offer  is valid  from Sep 22 to Dec 31. Avail this offer now!</p></div></div></a>]]

# %%
for offer in offers:
    for off in offer:
        titles.append(off.find('h3').get_text())
        By.append(off.find('p').find_all('span')[0].get_text())
        Valid_till.append(off.find('p').find_all('span')[1].get_text())
        Bank.append(off.find('p').find_all('span')[2].get_text())
        Deal_type.append(off.find('p').find_all('span')[3].get_text())
        Card_type.append(off.find('p').find_all('span')[4].get_text())

# %%
offers = pd.DataFrame({
'title': titles,
'by': By,
'valid_till': Valid_till,
'bank': Bank,
'deal_type': Deal_type,
'card_type':Card_type ,
})

# %%
offers.to_csv('offers.csv')

# %%
df = pd.read_csv('offers.csv')

# %%
df
# Out:
#     Unnamed: 0                                              title  \
# 0            0  Amazon EMI Offer - 3, 6, 9 & 12 Month EMI on A...
# 1            1  Flipkart EMI Offer- 3, 6, 9, 12, 18 and 24 Mon...
# 2            2             Avail Easy EMI on shopping on Flipkart
# 3            3  Avail Easy EMI & no Processing Fee on Amazon u...
# 4            4        Snapdeal EMI Offer - 3, 6, 9 & 12 Month EMI
# 5            5  Paytm EMI Offer - 3, 6, 9 & 12 Months EMI on P...
# 6            6           Yatra EMI Offer - 3, 6, 9 & 12 Month EMI
# 7            7      Bookmyshow EMI Offer - 3, 6, 9 & 12 Month EMI
# 8            8  Goibibo EMI Offer - 3, 6, 9 & 12 Month EMI on ...
# 9            9  Avail Easy EMI & no Processing Fee on Goibibo ...
# 10          10  Amazon EMI Offer - 3, 6, 9 & 12 Month EMI on A...
# 11          11  Flipkart EMI Offer- 3, 6, 9, 12, 18 and 24 Mon...
# 12          12             Avail Easy EMI on shopping on Flipkart
# 13          13  Avail Easy EMI & no Processing Fee on Amazon u...
# 14          14        Snapdeal EMI Offer - 3, 6, 9 & 12 Month EMI
# 15          15  Paytm EMI Offer - 3, 6, 9 & 12 Months EMI on P...
# 16          16           Yatra EMI Offer - 3, 6, 9 & 12 Month EMI
# 17          17      Bookmyshow EMI Offer - 3, 6, 9 & 12 Month EMI
# 18          18  Goibibo EMI Offer - 3, 6, 9 & 12 Month EMI on ...
# 19          19  Avail Easy EMI & no Processing Fee on Goibibo ...
# 20          20  Amazon EMI Offer - 3, 6, 9 & 12 Month EMI on A...
# 21          21  Flipkart EMI Offer- 3, 6, 9, 12, 18 and 24 Mon...
# 22          22             Avail Easy EMI on shopping on Flipkart
# 23          23  Avail Easy EMI & no Processing Fee on Amazon u...
# 24          24        Snapdeal EMI Offer - 3, 6, 9 & 12 Month EMI
# 25          25  Paytm EMI Offer - 3, 6, 9 & 12 Months EMI on P...
# 26          26           Yatra EMI Offer - 3, 6, 9 & 12 Month EMI
# 27          27      Bookmyshow EMI Offer - 3, 6, 9 & 12 Month EMI
# 28          28  Goibibo EMI Offer - 3, 6, 9 & 12 Month EMI on ...
# 29          29  Avail Easy EMI & no Processing Fee on Goibibo ...
#
#                  by                    valid_till  \
# 0       By : Amazon      Valid Till : Till Dec 31
# 1     By : Flipkart      Valid Till : Till Dec 31
# 2     By : Flipkart  Valid Till : Sep 22 - Dec 31
# 3       By : Amazon  Valid Till : Sep 22 - Dec 31
# 4     By : Snapdeal      Valid Till : Till Dec 31
# 5        By : Paytm      Valid Till : Till Mar 31
# 6        By : Yatra      Valid Till : Till Dec 31
# 7   By : BookMyShow      Valid Till : Till Dec 31
# 8      By : Goibibo      Valid Till : Till Dec 31
# 9      By : Goibibo  Valid Till : Sep 22 - Dec 31
# 10      By : Amazon      Valid Till : Till Dec 31
# 11    By : Flipkart      Valid Till : Till Dec 31
# 12    By : Flipkart  Valid Till : Sep 22 - Dec 31
# 13      By : Amazon  Valid Till : Sep 22 - Dec 31
# 14    By : Snapdeal      Valid Till : Till Dec 31
# 15       By : Paytm      Valid Till : Till Mar 31
# 16       By : Yatra      Valid Till : Till Dec 31
# 17  By : BookMyShow      Valid Till : Till Dec 31
# 18     By : Goibibo      Valid Till : Till Dec 31
# 19     By : Goibibo  Valid Till : Sep 22 - Dec 31
# 20      By : Amazon      Valid Till : Till Dec 31
# 21    By : Flipkart      Valid Till : Till Dec 31
# 22    By : Flipkart  Valid Till : Sep 22 - Dec 31
# 23      By : Amazon  Valid Till : Sep 22 - Dec 31
# 24    By : Snapdeal      Valid Till : Till Dec 31
# 25       By : Paytm      Valid Till : Till Mar 31
# 26       By : Yatra      Valid Till : Till Dec 31
# 27  By : BookMyShow      Valid Till : Till Dec 31
# 28     By : Goibibo      Valid Till : Till Dec 31
# 29     By : Goibibo  Valid Till : Sep 22 - Dec 31
#
#                            bank       deal_type          card_type
# 0   Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 1   Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 2   Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 3   Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 4   Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 5   Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 6   Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 7   Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 8   Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 9   Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 10  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 11  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 12  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 13  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 14  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 15  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 16  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 17  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 18  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 19  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 20  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 21  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 22  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 23  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 24  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 25  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 26  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 27  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 28  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit
# 29  Bank  : Kotak Mahindra Bank  Deal Type: EMI  Card Type: Credit

# %% [markdown]
# import schedule
# import time
#
# def job():
#     print("I'm working...")
#
# schedule.every(10).minutes.do(job)
# schedule.every().hour.do(job)
# schedule.every().day.at("10:30").do(job)
#
# while 1:
#     schedule.run_pending()
#     time.sleep(1)

# %%
from datetime import datetime
from threading import Timer

x=datetime.today()
y=x.replace(day=x.day+1, hour=1, minute=0, second=0, microsecond=0)
delta_t=y-x

secs=delta_t.seconds+1

def hello_world():
    print("hello world")
    #...

t = Timer(secs, hello_world)
t.start()

# %% [markdown]
# The scheduler can be achieved in two ways:
#     1)Through windows
#     2)Through linux
#     Cron is used in linux & unix basically

# %%
from crontab import CronTab
